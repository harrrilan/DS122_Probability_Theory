# %%
from scipy.stats import randint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Coockie Problem

# %%
distribution = pd.DataFrame(index=['first bowl', 'second bowl'])

#uniform prior distribution
# probs is prior!!!!
distribution['probs'] = randint(1, 3).pmf(np.arange(1,3)) 
distribution
# Out:
#              probs
# first bowl     0.5
# second bowl    0.5

# %%
plt.bar(distribution.index, distribution['probs'])
plt.title('Uniform prior distribution')
plt.xlabel('Bowl')
plt.ylabel('Probability')

plt.show()

# %%
def update(distribution, likelihood):
    '''perform a Bayesian update on distribution using likelihood'''
    distribution['probs'] = distribution['probs'] * likelihood
    prob_data = distribution['probs'].sum()
    distribution['probs'] = distribution['probs'] / prob_data
    return distribution

# %%
likelihood_vanilla = [0.75, 0.5]
update(distribution, likelihood_vanilla)
# Out:
#              probs
# first bowl     0.6
# second bowl    0.4

# %%
plt.bar(distribution.index, distribution['probs'])
plt.title('Uniform prior distribution')
plt.xlabel('Bowl')
plt.ylabel('Probability')

plt.show()

# %% [markdown]
# ## 101 Bowls

# %%
dist_101 = pd.DataFrame(index = np.arange(101))

# using a uniform prior distribution
dist_101['probs'] = randint(0, 101).pmf(np.arange(101)) 
dist_101
# Out:
#         probs
# 0    0.009901
# 1    0.009901
# 2    0.009901
# 3    0.009901
# 4    0.009901
# ..        ...
# 96   0.009901
# 97   0.009901
# 98   0.009901
# 99   0.009901
# 100  0.009901
#
# [101 rows x 1 columns]

# %%
plt.plot(dist_101.index, dist_101['probs'])
plt.title('Line plot for Uniform prior distribution')
plt.xlabel('Bowl')
plt.ylabel('Probability')

plt.show()
